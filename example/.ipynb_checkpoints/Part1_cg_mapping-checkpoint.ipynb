# %%
import torch
from torch import nn, optim
import matplotlib.pyplot as plt
import mdtraj as md
import math
from utils import save_traj
from cgae import *
import numpy as np
from cgae import *
import sys
sys.path.insert(0, '/home/jurgis/PAPER/')

from nff.utils.fixing_pbc import get_box_dimensions_pbc, split_mol, trajconv, combine_mol
from nff.utils.utilities import reorganize

# %%
# hyperparameters 
par = {}
par["n_atom"] = 25
par["N_cg"] = 4
par["lr"]  = 1e-4
par["batch_size"] = 20  
par["Tstart"] = 4.0      # starting temperature 
par["max_epoch"] = 40 
par["n_mol"] = 20         # number of molecules, 
par["epoch_regularize"] = 40    # first epoch to include instataneous force regularization
par["rho"] = 0.001       # relative weight for force regularization
par["decay_ratio"] = 0.4 # the decay rate for the temperature annealing 

device = 'cuda:0'

# otp_element = ['N', 'C', 'N', 'C', 'C', 'C', 'H', 'C', 'H', 'H', 'H',
#                'H', 'H', 'C', 'H', 'H', 'C', 'H', 'H', 'C', 'H', 'H', 'H', 'H', 'H']
# otp_element = ['N', 'C', 'N', 'C', 'C', 'C', 'C', 'C', 'C', 'C']
# otp_element = ['N', 'C', 'N', 'C', 'C', 'C', 'C', 'C', 'C', 'C']

# %%
N = 20
ils_mol = [[7, 6, 7, 6, 6, 6, 1, 6, 1, 1, 1, 1, 1, 6, 1, 1, 6, 1, 1, 6, 1, 1, 1, 1, 1],[5, 9, 9, 9, 9]]
N_cation = 25
N_anion = 5
N_atom = N_cation + N_anion
PATH = '/data/jurgis/dummy/all_atom_sample'
xyz_name = '{}/p20_nvt_sep_mol_xyz_T300_4.xyz'.format(PATH)
force_name = '{}/p20_nvt_sep_mol_force_T300_4.dat'.format(PATH)
N_cg = par["N_cg"]

# %%
ils_matrix, timestep_amount = split_mol(N, N_cation, N_anion, xyz_name)

cell = get_box_dimensions_pbc(force_name, timestep_amount)
# converted_mol = [[],[]]
converted_mol = []
# for i, ils in enumerate(ils_matrix):

# cell = get_box_dimensions_pbc(force_name, timestep_amount)
converted_mol = trajconv(N, ils_mol[0], cell, mol_matrix=ils_matrix[0])
    
# complete_traj = combine_mol(timestep_amount, converted_mol, N, N_atom, N_cation, N_anion, write=False)

force_full = reorganize(N_cation, N_anion, N, force_name, 'force')
# Out:
# Done sorting

# %%
traj = converted_mol.reshape(10001, 20, 25, 4)
traj = traj[:, :, :, 1:]

force = force_full[:, :, :25, :]
# traj = converted_mol.reshape(10001, 20, 25, 4)
# traj = traj[:, :, (0,1,2,3,4,5,7,13,16,19), 1:]
# force = force_full[:, :, (0,1,2,3,4,5,7,13,16,19), :]

# %%
# load data 
otp = md.load("data/otp.pdb")
otp_top = otp.top.to_dataframe()[0]
otp_element = otp_top['element'].values.tolist()
traj = np.load('data/otp_xyz.npy')
force = np.load('data/otp_force.npy')

# %%
# prepare data 
# traj = traj[-3000:] * 10
# force = force[-3000:] * 0.0239 
traj = traj[-3000:]
force = force[-3000:]

N_cg = par["N_cg"]
n_atom = par["n_atom"]
n_mol = par["n_mol"]
batch_size = par["batch_size"]
n_batch = int(traj.shape[0] // batch_size)
n_sample = n_batch * batch_size
xyz = traj[:n_sample].reshape(-1, batch_size, n_atom, 3)
force = force[:n_sample].reshape(-1, batch_size, n_atom, 3)
device = "cuda:0"

# %%
Encoder = encoder(in_dim=par["n_atom"], out_dim=par["N_cg"], hard=False, device=device).to(device)
Decoder = decoder(in_dim=par["N_cg"], out_dim=par["n_atom"]).to(device)

# Initialize Temperature Scheduler for Gumbel softmax 
t0 = par["Tstart"]
tmin = 0.2
temp = np.linspace(0, par["max_epoch"], par["max_epoch"] )

decay_epoch = int(par["max_epoch"] * par["decay_ratio"])
t_sched = t0 * np.exp(-temp/decay_epoch ) +  tmin
t_sched = torch.Tensor(t_sched).to(device)


# Initialize Optimizer 
criterion = torch.nn.MSELoss()
optimizer = optim.Adam(list(Encoder.parameters()) + list(Decoder.parameters()), lr=par["lr"]) 

loss_log = []
loss_ae_log = []
loss_fm_log = []

# %%
for epoch in range(par["max_epoch"]):  
# for epoch in range(1): 
        loss_epoch = 0.0  
        loss_ae_epoch = 0.0
        loss_fm_epoch = 0.0
        
            
        for i, batch in enumerate(xyz):
            batch = torch.Tensor(batch.reshape(-1, n_atom, 3)).to(device) 
            cg_xyz = Encoder(batch, t_sched[epoch])
            CG = gumbel_softmax(Encoder.weight1.t(), t_sched[epoch] * 0.7, device=device).t()

            decoded = Decoder(cg_xyz)
            loss_ae = criterion(decoded, batch)
            
            f0 = torch.Tensor(force[i].reshape(-1, n_atom, 3)).to(device)
            f = torch.matmul(CG, f0)
            
            if epoch > par["max_epoch"]-2:
                if i == 0:
                    forces_modified = f
                else:
                    forces_modified = torch.cat((forces_modified, f), 0)
            
            mean_force = f.pow(2).sum(2).sqrt().mean()

            loss_fm = par["rho"] * mean_force
            
            if epoch >= par["epoch_regularize"]:
                loss = loss_ae + loss_fm
            else: 
                loss = loss_ae

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            loss_epoch += loss.item()
            loss_ae_epoch += loss_ae.item()
            loss_fm_epoch += loss_fm.item()
        
        loss_epoch = loss_epoch/xyz.shape[0]
        loss_ae_epoch = loss_ae_epoch/xyz.shape[0]
        loss_fm_epoch = loss_fm_epoch/xyz.shape[0]

        loss_log.append(loss_epoch)
        loss_ae_log.append(loss_ae_epoch)
        loss_fm_log.append(loss_fm_epoch)

        print("epoch %d reconstruction  %.3f instantaneous forces %.3f  tau  %.3f"  % (epoch, loss_ae_epoch, loss_fm_epoch, t_sched[epoch].item()))

        # Plot the mapping 
        CG = gumbel_softmax(Encoder.weight1.t(), t_sched[epoch], device=device).t()
        plt.imshow(CG.detach().cpu().numpy(), aspect=4)
        plt.xticks(np.arange(n_atom), otp_element, fontsize=15)
        plt.yticks(np.arange(N_cg), ["CG" + str(i+1) for i in range(N_cg)], fontsize=20)
        plt.show()
# Out:
# epoch 0 reconstruction  0.040 instantaneous forces 1.148  tau  4.200
# epoch 1 reconstruction  0.039 instantaneous forces 1.193  tau  3.952
# epoch 2 reconstruction  0.039 instantaneous forces 1.226  tau  3.719
# epoch 3 reconstruction  0.038 instantaneous forces 1.275  tau  3.500
# epoch 4 reconstruction  0.038 instantaneous forces 1.305  tau  3.295
# epoch 5 reconstruction  0.038 instantaneous forces 1.360  tau  3.103
# epoch 6 reconstruction  0.038 instantaneous forces 1.402  tau  2.923
# epoch 7 reconstruction  0.037 instantaneous forces 1.454  tau  2.754
# epoch 8 reconstruction  0.037 instantaneous forces 1.513  tau  2.595
# epoch 9 reconstruction  0.037 instantaneous forces 1.551  tau  2.446
# epoch 10 reconstruction  0.037 instantaneous forces 1.602  tau  2.307
# epoch 11 reconstruction  0.036 instantaneous forces 1.674  tau  2.176
# epoch 12 reconstruction  0.036 instantaneous forces 1.718  tau  2.053
# epoch 13 reconstruction  0.036 instantaneous forces 1.780  tau  1.938
# epoch 14 reconstruction  0.035 instantaneous forces 1.811  tau  1.830
# epoch 15 reconstruction  0.035 instantaneous forces 1.868  tau  1.729
# epoch 16 reconstruction  0.034 instantaneous forces 1.942  tau  1.634
# epoch 17 reconstruction  0.034 instantaneous forces 2.003  tau  1.545
# epoch 18 reconstruction  0.033 instantaneous forces 2.067  tau  1.462
# epoch 19 reconstruction  0.033 instantaneous forces 2.097  tau  1.383
# epoch 20 reconstruction  0.032 instantaneous forces 2.167  tau  1.310
# epoch 21 reconstruction  0.032 instantaneous forces 2.185  tau  1.241
# epoch 22 reconstruction  0.031 instantaneous forces 2.271  tau  1.176
# epoch 23 reconstruction  0.030 instantaneous forces 2.299  tau  1.116
# epoch 24 reconstruction  0.030 instantaneous forces 2.370  tau  1.059
# epoch 25 reconstruction  0.029 instantaneous forces 2.389  tau  1.006
# epoch 26 reconstruction  0.029 instantaneous forces 2.420  tau  0.956
# epoch 27 reconstruction  0.028 instantaneous forces 2.477  tau  0.909
# epoch 28 reconstruction  0.028 instantaneous forces 2.526  tau  0.865
# epoch 29 reconstruction  0.027 instantaneous forces 2.534  tau  0.823
# epoch 30 reconstruction  0.027 instantaneous forces 2.568  tau  0.785
# epoch 31 reconstruction  0.026 instantaneous forces 2.622  tau  0.748
# epoch 32 reconstruction  0.025 instantaneous forces 2.643  tau  0.714
# epoch 33 reconstruction  0.025 instantaneous forces 2.690  tau  0.682
# epoch 34 reconstruction  0.025 instantaneous forces 2.693  tau  0.652
# epoch 35 reconstruction  0.024 instantaneous forces 2.741  tau  0.624
# epoch 36 reconstruction  0.024 instantaneous forces 2.718  tau  0.598
# epoch 37 reconstruction  0.024 instantaneous forces 2.753  tau  0.573
# epoch 38 reconstruction  0.023 instantaneous forces 2.788  tau  0.550
# epoch 39 reconstruction  0.023 instantaneous forces 2.799  tau  0.528

# %%
plt.imshow(CG.detach().cpu().numpy(), aspect=4)
plt.xticks(np.arange(n_atom), otp_element, fontsize=15)
plt.yticks(np.arange(N_cg), ["CG" + str(i+1) for i in range(N_cg)], fontsize=20)
plt.colorbar(orientation='horizontal')
plt.show()

# %%
forces_modified.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-fb79aa41cabd> in <module>
# ----> 1 forces_modified.shape
#
# NameError: name 'forces_modified' is not defined

# %%
forces_modified.pow(2).sum(2).sqrt().std()
# Out:
# tensor(17.7825, device='cuda:0', grad_fn=<StdBackward0>)

# %%
forces_modified.pow(2).sum(2).sqrt().mean()
# Out:
# tensor(31.7819, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
torch.Tensor(full_force).pow(2).sum(2).sqrt().std()
# Out:
# tensor(16.7975)

# %%
torch.Tensor(full_force).pow(2).sum(2).sqrt().mean()
# Out:
# tensor(19.7849)

# %%
# Save trajectory 
save_traj(Z=[1] * N_cg, traj=cg_xyz.detach().cpu().numpy(),name= 'CG.xyz')
save_traj(Z=otp_element, traj=decoded.detach().cpu().numpy(),name='decode.xyz')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b19d704a061d> in <module>
#       1 # Save trajectory
# ----> 2 save_traj(Z=[1] * N_cg, traj=cg_xyz.detach().cpu().numpy(),name= 'CG.xyz')
#       3 save_traj(Z=otp_element, traj=decoded.detach().cpu().numpy(),name='decode.xyz')
#
# NameError: name 'save_traj' is not defined

# %%
stan_force = (force - force.mean())/force.std()
stan_force_cg = (forces_modified - forces_modified.mean())/forces_modified.std()

# %%
force.flatten().shape
# Out:
# (4500000,)

# %%
forces_modified.flatten().shape
# Out:
# torch.Size([720000])

# %%
 

plt.figure(figsize=(12,8))
sns.distplot(stan_force.flatten(), bins=80, color='xkcd:red')
sns.distplot(stan_force_cg.cpu().detach().numpy().flatten(), bins=80, color='xkcd:darkgreen')

# plt.title('Standardized force distribution, 600 mol', fontsize = 40)

plt.legend(['GT','CG'], fontsize=30)

plt.xlabel(r'$Force, \frac{(F-\mu)}{\sigma}$', fontsize = 34)
plt.tick_params(labelsize=30)

# %%
batch
decoded

# %%
save_traj(Z=otp_element, traj=batch.detach().cpu().numpy(),name= 'traj_files/cg5_gt.xyz')
save_traj(Z=[1] * N_cg, traj=cg_xyz.detach().cpu().numpy(),name= 'traj_files/CG5_enc.xyz')
save_traj(Z=otp_element, traj=decoded.detach().cpu().numpy(),name='traj_files/cg5_dec.xyz')
